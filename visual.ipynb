# %%
import os
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
images = ['/x/vashishtm/data/medical/images/' + x for x in os.listdir('/x/vashishtm/data/medical/images/')]
labels = ['/x/vashishtm/data/medical/labels/' + x.split('/')[-1] for x in images]

# %%
plt.imshow(cv2.imread(images[1]))

# %%
plt.imshow(cv2.imread(labels[1])[:,:,0],cmap='gray')
